# %%
import numpy as np 
import matplotlib.pyplot as plt

v=np.array([2,3])
plt.plot ([1,v[0]],[2,v[1]])

v1=np.array([3,2])
plt.plot([2,v1[0]],[3,v1[1]])

v2=np.array([2.5,2.5])
plt.plot([1.5,v2[0]],[2.5,v2[1]])

v2=np.array([4,3])
plt.plot([4,v2[0]],[2,v2[1]])

v2=np.array([5,2.5])
plt.plot([4,v2[0]],[2.5,v2[1]])

v2=np.array([5,3])
plt.plot([5,v2[0]],[2,v2[1]])

v2=np.array([6.5,3])
plt.plot([6,v2[0]],[2,v2[1]])

v2=np.array([7,2.5])
plt.plot([6.5,v2[0]],[3,v2[1]])

v2=np.array([8,3])
plt.plot([7,v2[0]],[2.5,v2[1]])

v2=np.array([8,2])
plt.plot([8,v2[0]],[3,v2[1]])



v=np.array([9.5,3])
plt.plot ([9,v[0]],[2,v[1]])

v1=np.array([10,2])
plt.plot([9.5,v1[0]],[3,v1[1]])

v2=np.array([9.7,2.5])
plt.plot([9.3,v2[0]],[2.5,v2[1]])

v2=np.array([11,3])
plt.plot([11,v2[0]],[2,v2[1]])

v2=np.array([12,3])
plt.plot([11,v2[0]],[3,v2[1]])

v2=np.array([12,2])
plt.plot([12,v2[0]],[3,v2[1]])

v2=np.array([12,2])
plt.plot([12,v2[0]],[3,v2[1]])

v2=np.array([12,2])
plt.plot([11,v2[0]],[2,v2[1]])

v2=np.array([14,3])
plt.plot([14,v2[0]],[2,v2[1]])

v2=np.array([15,2])
plt.plot([14,v2[0]],[2,v2[1]])

v2=np.array([15,3])
plt.plot([15,v2[0]],[2,v2[1]])

v2=np.array([16,3])
plt.plot([16,v2[0]],[2,v2[1]])

v2=np.array([17,2])
plt.plot([16,v2[0]],[2,v2[1]])

v2=np.array([18,3])
plt.plot([18,v2[0]],[2,v2[1]])

v2=np.array([19,2])
plt.plot([18,v2[0]],[2,v2[1]])



v=np.array([21,3])
plt.plot ([20,v[0]],[2,v[1]])

v1=np.array([22,2])
plt.plot([21,v1[0]],[3,v1[1]])

v2=np.array([21.5,2.5])
plt.plot([20.4,v2[0]],[2.5,v2[1]])

v2=np.array([23,3])
plt.plot([23,v2[0]],[2,v2[1]])

v2=np.array([24,3])
plt.plot([24,v2[0]],[2,v2[1]])

v2=np.array([24,2.5])
plt.plot([23,v2[0]],[2.5,v2[1]])


plt.axis([0,30,-4,4])
